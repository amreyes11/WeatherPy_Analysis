# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude 
np.random.uniform(-90.000, 90.000)
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=999828d3dd4a17ae93c1bce024561d1c

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
                 
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date}) 
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | morondava
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | alice springs
# Processing Record 5 of Set 1 | karmaskaly
# Processing Record 6 of Set 1 | filadelfia
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | abbeville
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | comodoro rivadavia
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | guerrero negro
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | bonthe
# Processing Record 16 of Set 1 | sinnamary
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | northam
# Processing Record 19 of Set 1 | esperance
# Processing Record 20 of Set 1 | san cristobal
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | krasnoyarsk
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | le vauclin
# Processing Record 26 of Set 1 | sheksna
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | vao
# Processing Record 30 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 1 | half moon bay
# Processing Record 32 of Set 1 | takoradi
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | catamarca
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | touros
# Processing Record 39 of Set 1 | dasoguz
# Processing Record 40 of Set 1 | zaysan
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | nacala
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | peniche
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | salalah
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | tual
# Processing Record 2 of Set 2 | lorengau
# Processing Record 3 of Set 2 | bathsheba
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | sitka
# Processing Record 6 of Set 2 | ponta pora
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | revelstoke
# Processing Record 9 of Set 2 | fernie
# Processing Record 10 of Set 2 | ajdabiya
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | mwene-ditu
# Processing Record 13 of Set 2 | wau
# Processing Record 14 of Set 2 | klaksvik
# Processing Record 15 of Set 2 | bandarbeyla
# Processing Record 16 of Set 2 | zhigansk
# Processing Record 17 of Set 2 | college
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | ternate
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | lagoa
# Processing Record 23 of Set 2 | rikitea
# Processing Record 24 of Set 2 | healdsburg
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 2 | yar-sale
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | nizwa
# Processing Record 30 of Set 2 | kathmandu
# Processing Record 31 of Set 2 | bambous virieux
# Processing Record 32 of Set 2 | bjala
# City not found. Skipping...
# Processing Record 33 of Set 2 | magadan
# Processing Record 34 of Set 2 | izhma
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | mantsala
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | quatre cocos
# Processing Record 39 of Set 2 | alanya
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | cabra
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | mataura
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | lata
# Processing Record 47 of Set 2 | gunjur
# Processing Record 48 of Set 2 | quzhou
# Processing Record 49 of Set 2 | goias
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 2 of Set 3 | lere
# Processing Record 3 of Set 3 | karratha
# Processing Record 4 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 3 | emerald
# Processing Record 6 of Set 3 | punta arenas
# Processing Record 7 of Set 3 | grindavik
# Processing Record 8 of Set 3 | santa cruz cabralia
# Processing Record 9 of Set 3 | ayolas
# Processing Record 10 of Set 3 | kasungu
# Processing Record 11 of Set 3 | asfi
# Processing Record 12 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 3 | priargunsk
# Processing Record 14 of Set 3 | castro
# Processing Record 15 of Set 3 | ovalle
# Processing Record 16 of Set 3 | hasaki
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | taoudenni
# Processing Record 19 of Set 3 | verkhnyaya inta
# Processing Record 20 of Set 3 | port lincoln
# Processing Record 21 of Set 3 | tanete
# Processing Record 22 of Set 3 | puerto colombia
# Processing Record 23 of Set 3 | marechal candido rondon
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | carnarvon
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | bairiki
# Processing Record 28 of Set 3 | chicama
# Processing Record 29 of Set 3 | ulladulla
# Processing Record 30 of Set 3 | muzhi
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | wenling
# Processing Record 35 of Set 3 | santa isabel
# Processing Record 36 of Set 3 | bikaner
# Processing Record 37 of Set 3 | cabinda
# Processing Record 38 of Set 3 | aksu
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | shamary
# Processing Record 41 of Set 3 | zhob
# Processing Record 42 of Set 3 | nelson bay
# Processing Record 43 of Set 3 | santa cruz
# Processing Record 44 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 3 | praia
# Processing Record 46 of Set 3 | powell river
# Processing Record 47 of Set 3 | tondano
# Processing Record 48 of Set 3 | saldanha
# Processing Record 49 of Set 3 | crib point
# Processing Record 50 of Set 3 | poya
# Processing Record 1 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | barcelos
# Processing Record 4 of Set 4 | maiduguri
# Processing Record 5 of Set 4 | savalou
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | manggar
# Processing Record 8 of Set 4 | barra patuca
# Processing Record 9 of Set 4 | san-pedro
# Processing Record 10 of Set 4 | halifax
# Processing Record 11 of Set 4 | tongliao
# Processing Record 12 of Set 4 | saint-francois
# Processing Record 13 of Set 4 | kelvington
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | amapa
# Processing Record 16 of Set 4 | severo-kurilsk
# Processing Record 17 of Set 4 | fort nelson
# Processing Record 18 of Set 4 | meulaboh
# Processing Record 19 of Set 4 | sharjah
# Processing Record 20 of Set 4 | vanimo
# Processing Record 21 of Set 4 | yurla
# Processing Record 22 of Set 4 | jamestown
# Processing Record 23 of Set 4 | beya
# Processing Record 24 of Set 4 | sestri levante
# Processing Record 25 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 4 | noyabrsk
# Processing Record 27 of Set 4 | turukhansk
# Processing Record 28 of Set 4 | nicoya
# Processing Record 29 of Set 4 | acapulco
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | pochutla
# Processing Record 32 of Set 4 | hambantota
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | goksun
# Processing Record 35 of Set 4 | aligudarz
# Processing Record 36 of Set 4 | port blair
# Processing Record 37 of Set 4 | norman wells
# Processing Record 38 of Set 4 | calabozo
# Processing Record 39 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 40 of Set 4 | antigonish
# Processing Record 41 of Set 4 | hilo
# Processing Record 42 of Set 4 | gamboula
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | henties bay
# Processing Record 46 of Set 4 | dikson
# Processing Record 47 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 4 | tanout
# Processing Record 49 of Set 4 | ndjole
# Processing Record 50 of Set 4 | marv dasht
# City not found. Skipping...
# Processing Record 1 of Set 5 | tasiilaq
# Processing Record 2 of Set 5 | avera
# Processing Record 3 of Set 5 | rio gallegos
# Processing Record 4 of Set 5 | kaeo
# Processing Record 5 of Set 5 | dakar
# Processing Record 6 of Set 5 | kropotkin
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | zhumadian
# Processing Record 10 of Set 5 | hay river
# Processing Record 11 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 5 | eyl
# Processing Record 14 of Set 5 | havelock
# Processing Record 15 of Set 5 | merauke
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | namie
# Processing Record 20 of Set 5 | nanortalik
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | massaguet
# Processing Record 23 of Set 5 | itarema
# Processing Record 24 of Set 5 | iqaluit
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | provideniya
# Processing Record 28 of Set 5 | olafsvik
# Processing Record 29 of Set 5 | puerto narino
# Processing Record 30 of Set 5 | kodiak
# Processing Record 31 of Set 5 | carutapera
# Processing Record 32 of Set 5 | lazarev
# Processing Record 33 of Set 5 | gamba
# Processing Record 34 of Set 5 | riosucio
# Processing Record 35 of Set 5 | mersing
# Processing Record 36 of Set 5 | namatanai
# Processing Record 37 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 38 of Set 5 | kirakira
# Processing Record 39 of Set 5 | butaritari
# Processing Record 40 of Set 5 | bosaso
# Processing Record 41 of Set 5 | matadi
# Processing Record 42 of Set 5 | bradford
# Processing Record 43 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 44 of Set 5 | pacifica
# Processing Record 45 of Set 5 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 5 | roxas
# Processing Record 47 of Set 5 | newport
# Processing Record 48 of Set 5 | makakilo city
# Processing Record 49 of Set 5 | longyearbyen
# Processing Record 50 of Set 5 | dingle
# Processing Record 1 of Set 6 | sayansk
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | alta floresta
# Processing Record 4 of Set 6 | kismayo
# Processing Record 5 of Set 6 | champerico
# Processing Record 6 of Set 6 | mount gambier
# Processing Record 7 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 6 | salvador
# Processing Record 9 of Set 6 | smidovich
# Processing Record 10 of Set 6 | talaya
# Processing Record 11 of Set 6 | arlit
# Processing Record 12 of Set 6 | ulagan
# Processing Record 13 of Set 6 | nemuro
# Processing Record 14 of Set 6 | narsaq
# Processing Record 15 of Set 6 | choma
# Processing Record 16 of Set 6 | garissa
# Processing Record 17 of Set 6 | constitucion
# Processing Record 18 of Set 6 | souillac
# Processing Record 19 of Set 6 | tiksi
# Processing Record 20 of Set 6 | dinsor
# City not found. Skipping...
# Processing Record 21 of Set 6 | bubaque
# Processing Record 22 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 6 | houma
# Processing Record 24 of Set 6 | fortuna
# Processing Record 25 of Set 6 | manturovo
# Processing Record 26 of Set 6 | khorinsk
# Processing Record 27 of Set 6 | shieli
# Processing Record 28 of Set 6 | saryozek
# Processing Record 29 of Set 6 | malanje
# Processing Record 30 of Set 6 | simga
# Processing Record 31 of Set 6 | altamont
# Processing Record 32 of Set 6 | illapel
# Processing Record 33 of Set 6 | delmiro gouveia
# Processing Record 34 of Set 6 | katsuura
# Processing Record 35 of Set 6 | port hardy
# Processing Record 36 of Set 6 | naze
# Processing Record 37 of Set 6 | pozo colorado
# Processing Record 38 of Set 6 | egvekinot
# Processing Record 39 of Set 6 | nouadhibou
# Processing Record 40 of Set 6 | garavuti
# Processing Record 41 of Set 6 | bonavista
# Processing Record 42 of Set 6 | ostrovnoy
# Processing Record 43 of Set 6 | dunedin
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | asosa
# Processing Record 46 of Set 6 | cozumel
# Processing Record 47 of Set 6 | husavik
# Processing Record 48 of Set 6 | oranjestad
# Processing Record 49 of Set 6 | pisco
# Processing Record 50 of Set 6 | rocha
# Processing Record 1 of Set 7 | vanavara
# Processing Record 2 of Set 7 | gao
# Processing Record 3 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 4 of Set 7 | high level
# Processing Record 5 of Set 7 | lompoc
# Processing Record 6 of Set 7 | faanui
# Processing Record 7 of Set 7 | padang
# Processing Record 8 of Set 7 | torbay
# Processing Record 9 of Set 7 | salamiyah
# Processing Record 10 of Set 7 | yuanping
# Processing Record 11 of Set 7 | shiyan
# Processing Record 12 of Set 7 | hanzhong
# Processing Record 13 of Set 7 | nara
# Processing Record 14 of Set 7 | hofn
# Processing Record 15 of Set 7 | severodvinsk
# Processing Record 16 of Set 7 | pimentel
# Processing Record 17 of Set 7 | dali
# Processing Record 18 of Set 7 | oranjemund
# Processing Record 19 of Set 7 | ginir
# Processing Record 20 of Set 7 | bolshoye murashkino
# Processing Record 21 of Set 7 | nyurba
# Processing Record 22 of Set 7 | sao joao da barra
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | aswan
# Processing Record 25 of Set 7 | kamenka
# Processing Record 26 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 7 | high rock
# Processing Record 28 of Set 7 | san quintin
# Processing Record 29 of Set 7 | mandalgovi
# Processing Record 30 of Set 7 | mehamn
# Processing Record 31 of Set 7 | port-gentil
# Processing Record 32 of Set 7 | kutum
# Processing Record 33 of Set 7 | raton
# Processing Record 34 of Set 7 | victoria
# Processing Record 35 of Set 7 | van
# Processing Record 36 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 37 of Set 7 | otradnoye
# Processing Record 38 of Set 7 | malpe
# Processing Record 39 of Set 7 | moirai
# City not found. Skipping...
# Processing Record 40 of Set 7 | bwanga
# Processing Record 41 of Set 7 | kruisfontein
# Processing Record 42 of Set 7 | sidi ali
# Processing Record 43 of Set 7 | wuzhou
# Processing Record 44 of Set 7 | te anau
# Processing Record 45 of Set 7 | mar del plata
# Processing Record 46 of Set 7 | impfondo
# Processing Record 47 of Set 7 | mandan
# Processing Record 48 of Set 7 | russell
# Processing Record 49 of Set 7 | moose factory
# Processing Record 50 of Set 7 | moen
# Processing Record 1 of Set 8 | bilibino
# Processing Record 2 of Set 8 | birin
# Processing Record 3 of Set 8 | copperas cove
# Processing Record 4 of Set 8 | saskylakh
# Processing Record 5 of Set 8 | tuatapere
# Processing Record 6 of Set 8 | aklavik
# Processing Record 7 of Set 8 | los llanos de aridane
# Processing Record 8 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 9 of Set 8 | tirumala
# Processing Record 10 of Set 8 | humberto de campos
# Processing Record 11 of Set 8 | bayji
# Processing Record 12 of Set 8 | kachiry
# Processing Record 13 of Set 8 | oistins
# Processing Record 14 of Set 8 | qandala
# Processing Record 15 of Set 8 | assen
# Processing Record 16 of Set 8 | pizarro
# Processing Record 17 of Set 8 | covington
# Processing Record 18 of Set 8 | udachnyy
# Processing Record 19 of Set 8 | novyy urengoy
# Processing Record 20 of Set 8 | adrar
# Processing Record 21 of Set 8 | cidreira
# Processing Record 22 of Set 8 | clyde river
# Processing Record 23 of Set 8 | zhezkazgan
# Processing Record 24 of Set 8 | itabera
# Processing Record 25 of Set 8 | sur
# Processing Record 26 of Set 8 | perehonivka
# Processing Record 27 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 28 of Set 8 | praia da vitoria
# Processing Record 29 of Set 8 | naliya
# Processing Record 30 of Set 8 | abu dhabi
# Processing Record 31 of Set 8 | fereydunshahr
# Processing Record 32 of Set 8 | kailua
# Processing Record 33 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of Set 8 | vila velha
# Processing Record 35 of Set 8 | dzaoudzi
# Processing Record 36 of Set 8 | tutoia
# Processing Record 37 of Set 8 | hope
# Processing Record 38 of Set 8 | broken hill
# Processing Record 39 of Set 8 | aginskoye
# Processing Record 40 of Set 8 | nakhon phanom
# Processing Record 41 of Set 8 | mitu
# Processing Record 42 of Set 8 | ihosy
# Processing Record 43 of Set 8 | porto walter
# Processing Record 44 of Set 8 | okhotsk
# Processing Record 45 of Set 8 | meaford
# Processing Record 46 of Set 8 | esfahan
# Processing Record 47 of Set 8 | chake chake
# Processing Record 48 of Set 8 | lhuntshi
# City not found. Skipping...
# Processing Record 49 of Set 8 | vardo
# Processing Record 50 of Set 8 | saint george
# Processing Record 1 of Set 9 | male
# Processing Record 2 of Set 9 | turbat
# Processing Record 3 of Set 9 | orsha
# Processing Record 4 of Set 9 | cedar city
# Processing Record 5 of Set 9 | okha
# Processing Record 6 of Set 9 | hami
# Processing Record 7 of Set 9 | smithers
# Processing Record 8 of Set 9 | da nang
# Processing Record 9 of Set 9 | valea danului
# Processing Record 10 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 9 | codrington
# Processing Record 12 of Set 9 | matara
# Processing Record 13 of Set 9 | komsomolskiy
# Processing Record 14 of Set 9 | tianpeng
# Processing Record 15 of Set 9 | nizhniy tsasuchey
# Processing Record 16 of Set 9 | bereda
# Processing Record 17 of Set 9 | maltahohe
# Processing Record 18 of Set 9 | alekseyevsk
# Processing Record 19 of Set 9 | wasilla
# Processing Record 20 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 9 | san vicente
# Processing Record 22 of Set 9 | madison
# Processing Record 23 of Set 9 | shimoda
# Processing Record 24 of Set 9 | kendari
# Processing Record 25 of Set 9 | anadyr
# Processing Record 26 of Set 9 | bangkal
# Processing Record 27 of Set 9 | san andres
# Processing Record 28 of Set 9 | mackay
# Processing Record 29 of Set 9 | atasu
# Processing Record 30 of Set 9 | ayagoz
# Processing Record 31 of Set 9 | ustka
# Processing Record 32 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 9 | sola
# Processing Record 34 of Set 9 | coihaique
# Processing Record 35 of Set 9 | bajil
# Processing Record 36 of Set 9 | taltal
# Processing Record 37 of Set 9 | kilindoni
# Processing Record 38 of Set 9 | adet
# Processing Record 39 of Set 9 | sobolevo
# Processing Record 40 of Set 9 | caluquembe
# Processing Record 41 of Set 9 | christchurch
# Processing Record 42 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 43 of Set 9 | yoichi
# Processing Record 44 of Set 9 | yulara
# Processing Record 45 of Set 9 | duncanville
# Processing Record 46 of Set 9 | dois vizinhos
# Processing Record 47 of Set 9 | yerbogachen
# Processing Record 48 of Set 9 | sisimiut
# Processing Record 49 of Set 9 | urucara
# Processing Record 50 of Set 9 | sorland
# Processing Record 1 of Set 10 | londa
# Processing Record 2 of Set 10 | shumskiy
# Processing Record 3 of Set 10 | shasta lake
# Processing Record 4 of Set 10 | lagarto
# Processing Record 5 of Set 10 | povenets
# Processing Record 6 of Set 10 | svetlaya
# Processing Record 7 of Set 10 | faya
# Processing Record 8 of Set 10 | nenjiang
# Processing Record 9 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 10 | belokurikha
# Processing Record 11 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 10 | kahului
# Processing Record 13 of Set 10 | buala
# Processing Record 14 of Set 10 | srednekolymsk
# Processing Record 15 of Set 10 | kuliyapitiya
# Processing Record 16 of Set 10 | midland
# Processing Record 17 of Set 10 | hailar
# Processing Record 18 of Set 10 | portland
# Processing Record 19 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 10 | ketchikan
# Processing Record 21 of Set 10 | adzhamka
# Processing Record 22 of Set 10 | bindi
# Processing Record 23 of Set 10 | zhuhai
# Processing Record 24 of Set 10 | angoche
# Processing Record 25 of Set 10 | launceston
# Processing Record 26 of Set 10 | jalu
# Processing Record 27 of Set 10 | tilichiki
# Processing Record 28 of Set 10 | makung
# City not found. Skipping...
# Processing Record 29 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 30 of Set 10 | osakarovka
# Processing Record 31 of Set 10 | opobo
# City not found. Skipping...
# Processing Record 32 of Set 10 | khilok
# Processing Record 33 of Set 10 | korla
# Processing Record 34 of Set 10 | batken
# Processing Record 35 of Set 10 | ampanihy
# Processing Record 36 of Set 10 | imeni poliny osipenko
# Processing Record 37 of Set 10 | lima
# Processing Record 38 of Set 10 | tenango
# Processing Record 39 of Set 10 | carballo
# Processing Record 40 of Set 10 | odweyne
# Processing Record 41 of Set 10 | manzil salim
# Processing Record 42 of Set 10 | gornopravdinsk
# Processing Record 43 of Set 10 | nantucket
# Processing Record 44 of Set 10 | asau
# Processing Record 45 of Set 10 | puerto lopez
# Processing Record 46 of Set 10 | harper
# Processing Record 47 of Set 10 | teknaf
# Processing Record 48 of Set 10 | terrak
# Processing Record 49 of Set 10 | shingu
# Processing Record 50 of Set 10 | huarmey
# Processing Record 1 of Set 11 | prince albert
# Processing Record 2 of Set 11 | hervey bay
# Processing Record 3 of Set 11 | fukumitsu
# Processing Record 4 of Set 11 | tefe
# Processing Record 5 of Set 11 | sukumo
# Processing Record 6 of Set 11 | san policarpo
# Processing Record 7 of Set 11 | ureki
# Processing Record 8 of Set 11 | multai
# Processing Record 9 of Set 11 | paamiut
# Processing Record 10 of Set 11 | cartagena del chaira
# Processing Record 11 of Set 11 | quezon
# Processing Record 12 of Set 11 | novikovo
# Processing Record 13 of Set 11 | khani
# Processing Record 14 of Set 11 | morehead
# Processing Record 15 of Set 11 | akhnur
# Processing Record 16 of Set 11 | itapirapua
# Processing Record 17 of Set 11 | rudnichnyy
# Processing Record 18 of Set 11 | flin flon
# Processing Record 19 of Set 11 | erzin
# Processing Record 20 of Set 11 | sao filipe
# Processing Record 21 of Set 11 | honiara
# Processing Record 22 of Set 11 | escarcega
# Processing Record 23 of Set 11 | ishigaki
# Processing Record 24 of Set 11 | stromness
# Processing Record 25 of Set 11 | dmitriyevka
# Processing Record 26 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 11 | seoul
# Processing Record 28 of Set 11 | liverpool
# Processing Record 29 of Set 11 | simplicio mendes
# Processing Record 30 of Set 11 | belyy yar
# Processing Record 31 of Set 11 | filingue
# Processing Record 32 of Set 11 | peleduy
# Processing Record 33 of Set 11 | fairbanks
# Processing Record 34 of Set 11 | sirari
# Processing Record 35 of Set 11 | les cayes
# Processing Record 36 of Set 11 | gambela
# Processing Record 37 of Set 11 | cap malheureux
# Processing Record 38 of Set 11 | ximei
# Processing Record 39 of Set 11 | vetluzhskiy
# Processing Record 40 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 41 of Set 11 | orlik
# Processing Record 42 of Set 11 | ridgecrest
# Processing Record 43 of Set 11 | labuhan
# Processing Record 44 of Set 11 | alofi
# Processing Record 45 of Set 11 | vagay
# Processing Record 46 of Set 11 | adria
# Processing Record 47 of Set 11 | caravelas
# Processing Record 48 of Set 11 | la ronge
# Processing Record 49 of Set 11 | cherskiy
# Processing Record 50 of Set 11 | lively
# Processing Record 1 of Set 12 | lahat
# Processing Record 2 of Set 12 | alto araguaia
# Processing Record 3 of Set 12 | wysokie mazowieckie
# Processing Record 4 of Set 12 | wana
# Processing Record 5 of Set 12 | marawi
# Processing Record 6 of Set 12 | ponta delgada
# Processing Record 7 of Set 12 | jian
# Processing Record 8 of Set 12 | pokhara
# Processing Record 9 of Set 12 | calimete
# Processing Record 10 of Set 12 | severobaykalsk
# Processing Record 11 of Set 12 | kedgwick
# Processing Record 12 of Set 12 | grand gaube
# Processing Record 13 of Set 12 | imbituba
# Processing Record 14 of Set 12 | namibe
# Processing Record 15 of Set 12 | vestmannaeyjar
# Processing Record 16 of Set 12 | khartoum
# Processing Record 17 of Set 12 | broome
# Processing Record 18 of Set 12 | price
# Processing Record 19 of Set 12 | inongo
# Processing Record 20 of Set 12 | byron bay
# Processing Record 21 of Set 12 | mantua
# Processing Record 22 of Set 12 | adilabad
# Processing Record 23 of Set 12 | ilulissat
# Processing Record 24 of Set 12 | podor
# Processing Record 25 of Set 12 | hermon
# Processing Record 26 of Set 12 | beira
# Processing Record 27 of Set 12 | sahuaripa
# Processing Record 28 of Set 12 | karla
# Processing Record 29 of Set 12 | san patricio
# Processing Record 30 of Set 12 | calamar
# Processing Record 31 of Set 12 | aras
# Processing Record 32 of Set 12 | seymchan
# Processing Record 33 of Set 12 | ust-maya
# Processing Record 34 of Set 12 | dir
# Processing Record 35 of Set 12 | mayor pablo lagerenza
# Processing Record 36 of Set 12 | jimenez
# Processing Record 37 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 12 | dolores
# Processing Record 39 of Set 12 | jijiga
# Processing Record 40 of Set 12 | saint-augustin
# Processing Record 41 of Set 12 | helong
# Processing Record 42 of Set 12 | reporoa
# Processing Record 43 of Set 12 | synya
# Processing Record 44 of Set 12 | vesoul
# Processing Record 45 of Set 12 | sungai siput utara
# City not found. Skipping...
# Processing Record 46 of Set 12 | atar
# Processing Record 47 of Set 12 | gimli
# Processing Record 48 of Set 12 | palembang
# Processing Record 49 of Set 12 | mildura
# Processing Record 50 of Set 12 | aberdeen
# Processing Record 1 of Set 13 | bilma
# Processing Record 2 of Set 13 | kuusamo
# Processing Record 3 of Set 13 | sale
# Processing Record 4 of Set 13 | varia
# Processing Record 5 of Set 13 | itambacuri
# Processing Record 6 of Set 13 | mujiayingzi
# Processing Record 7 of Set 13 | blagoyevo
# Processing Record 8 of Set 13 | santa fe
# Processing Record 9 of Set 13 | kudahuvadhoo
# Processing Record 10 of Set 13 | lexington
# Processing Record 11 of Set 13 | ropczyce
# Processing Record 12 of Set 13 | mogadishu
# Processing Record 13 of Set 13 | phan thiet
# Processing Record 14 of Set 13 | batagay-alyta
# Processing Record 15 of Set 13 | manga
# Processing Record 16 of Set 13 | lucea
# Processing Record 17 of Set 13 | hudson bay
# Processing Record 18 of Set 13 | grootfontein
# Processing Record 19 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 13 | tecpatan
# Processing Record 21 of Set 13 | deputatskiy
# Processing Record 22 of Set 13 | zirandaro
# Processing Record 23 of Set 13 | vung tau
# Processing Record 24 of Set 13 | katobu
# Processing Record 25 of Set 13 | tevaitoa
# Processing Record 26 of Set 13 | ust-kuyga
# Processing Record 27 of Set 13 | nova russas
# Processing Record 28 of Set 13 | port macquarie
# Processing Record 29 of Set 13 | coahuayana
# Processing Record 30 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 31 of Set 13 | balabac
# Processing Record 32 of Set 13 | kigoma
# Processing Record 33 of Set 13 | trincomalee
# Processing Record 34 of Set 13 | malibu
# Processing Record 35 of Set 13 | kumba
# Processing Record 36 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 37 of Set 13 | ilebo
# Processing Record 38 of Set 13 | cabuyaro
# Processing Record 39 of Set 13 | boda
# Processing Record 40 of Set 13 | umm lajj
# Processing Record 41 of Set 13 | lafiagi
# Processing Record 42 of Set 13 | aloleng
# Processing Record 43 of Set 13 | anloga
# Processing Record 44 of Set 13 | hualmay
# Processing Record 45 of Set 13 | santiago
# Processing Record 46 of Set 13 | nigde
# Processing Record 47 of Set 13 | mihail kogalniceanu
# Processing Record 48 of Set 13 | narasannapeta
# Processing Record 49 of Set 13 | hoquiam
# Processing Record 50 of Set 13 | waksma
# City not found. Skipping...
# Processing Record 1 of Set 14 | portree
# Processing Record 2 of Set 14 | alyangula
# Processing Record 3 of Set 14 | winkler
# Processing Record 4 of Set 14 | coos bay
# Processing Record 5 of Set 14 | onokhino
# Processing Record 6 of Set 14 | darnah
# Processing Record 7 of Set 14 | glenwood springs
# Processing Record 8 of Set 14 | tougue
# Processing Record 9 of Set 14 | sarany
# Processing Record 10 of Set 14 | pangoa
# Processing Record 11 of Set 14 | katherine
# Processing Record 12 of Set 14 | tiarei
# Processing Record 13 of Set 14 | boa vista
# Processing Record 14 of Set 14 | nouakchott
# Processing Record 15 of Set 14 | kibaya
# Processing Record 16 of Set 14 | baykit
# Processing Record 17 of Set 14 | hua hin
# Processing Record 18 of Set 14 | severnyy
# Processing Record 19 of Set 14 | rolla
# Processing Record 20 of Set 14 | iquique
# Processing Record 21 of Set 14 | batticaloa
# Processing Record 22 of Set 14 | ust-ilimsk
# Processing Record 23 of Set 14 | mwinilunga
# Processing Record 24 of Set 14 | kabanjahe
# Processing Record 25 of Set 14 | porto novo
# Processing Record 26 of Set 14 | tacoronte
# Processing Record 27 of Set 14 | mbala
# Processing Record 28 of Set 14 | kashi
# Processing Record 29 of Set 14 | port moresby
# Processing Record 30 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 14 | candolim
# Processing Record 32 of Set 14 | ciudad bolivar
# Processing Record 33 of Set 14 | micomeseng
# Processing Record 34 of Set 14 | turek
# Processing Record 35 of Set 14 | cayenne
# Processing Record 36 of Set 14 | sibay
# Processing Record 37 of Set 14 | kongolo
# Processing Record 38 of Set 14 | maniitsoq
# Processing Record 39 of Set 14 | warwick
# Processing Record 40 of Set 14 | lodja
# Processing Record 41 of Set 14 | urumqi
# Processing Record 42 of Set 14 | leeuwarden
# Processing Record 43 of Set 14 | soligalich
# Processing Record 44 of Set 14 | hobyo
# Processing Record 45 of Set 14 | rincon
# Processing Record 46 of Set 14 | semirom
# Processing Record 47 of Set 14 | owando
# Processing Record 48 of Set 14 | orotukan
# Processing Record 49 of Set 14 | uyskoye
# Processing Record 50 of Set 14 | rognan
# Processing Record 1 of Set 15 | camacari
# Processing Record 2 of Set 15 | kraslava
# Processing Record 3 of Set 15 | gbarnga
# Processing Record 4 of Set 15 | robertsport
# Processing Record 5 of Set 15 | uchiza
# Processing Record 6 of Set 15 | masuguru
# Processing Record 7 of Set 15 | kuldur
# Processing Record 8 of Set 15 | kingisepp
# Processing Record 9 of Set 15 | omboue
# Processing Record 10 of Set 15 | kununurra
# Processing Record 11 of Set 15 | karakol
# Processing Record 12 of Set 15 | kieta
# Processing Record 13 of Set 15 | abu kamal
# Processing Record 14 of Set 15 | irbeyskoye
# Processing Record 15 of Set 15 | buraydah
# Processing Record 16 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 15 | puerto del rosario
# Processing Record 18 of Set 15 | gravdal
# Processing Record 19 of Set 15 | tura
# Processing Record 20 of Set 15 | aromashevo
# Processing Record 21 of Set 15 | harer
# Processing Record 22 of Set 15 | antofagasta
# Processing Record 23 of Set 15 | chiuza
# Processing Record 24 of Set 15 | libreville
# Processing Record 25 of Set 15 | macusani
# Processing Record 26 of Set 15 | the valley
# Processing Record 27 of Set 15 | oga
# Processing Record 28 of Set 15 | beloha
# Processing Record 29 of Set 15 | birao
# Processing Record 30 of Set 15 | onverwacht
# Processing Record 31 of Set 15 | ambon
# Processing Record 32 of Set 15 | hirara
# Processing Record 33 of Set 15 | santa catarina de tepehuanes
# Processing Record 34 of Set 15 | teya
# Processing Record 35 of Set 15 | yarada
# Processing Record 36 of Set 15 | sarahan
# Processing Record 37 of Set 15 | plettenberg bay
# Processing Record 38 of Set 15 | sept-iles
# Processing Record 39 of Set 15 | longhua
# Processing Record 40 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 15 | awjilah
# Processing Record 42 of Set 15 | reynosa
# Processing Record 43 of Set 15 | clarksville
# Processing Record 44 of Set 15 | quchan
# Processing Record 45 of Set 15 | garowe
# Processing Record 46 of Set 15 | abengourou
# Processing Record 47 of Set 15 | bennington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 690

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Morondava -20.2833   44.2833     84.52        61          39
# 1         New Norfolk -42.7826  147.0587     69.93        27           0
# 2              Barrow  71.2906 -156.7887     -0.38        71          40
# 3       Alice Springs -23.7000  133.8833     92.75        40          40
# 4          Karmaskaly  54.3709   56.1837     -4.09        90          99
# 5          Filadelfia  39.9523  -75.1638     31.10        69          75
# 6           Abbeville  50.1000    1.8333     46.36        73          77
# 7           Busselton -33.6500  115.3333     79.16        38           0
# 8  Comodoro Rivadavia -45.8667  -67.5000     49.86        87           0
# 9            Thompson  55.7435  -97.8558     -0.24        85         100
#
#    Wind Speed Country                 Date
# 0        2.98      MG  2023-01-15 06:36:47
# 1        5.01      AU  2023-01-15 06:36:48
# 2       20.71      US  2023-01-15 06:36:48
# 3       19.57      AU  2023-01-15 06:32:22
# 4        9.48      RU  2023-01-15 06:36:49
# 5       16.11      US  2023-01-15 06:34:37
# 6       19.39      FR  2023-01-15 06:36:49
# 7       16.08      AU  2023-01-15 06:36:50
# 8        3.44      AR  2023-01-15 06:36:50
# 9        8.05      CA  2023-01-15 06:36:51

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city = city_data_df["City"]
country = city_data_df["Country"]
lng = city_data_df["Lng"]
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
date = city_data_df["Date"]

# Recreate the DataFrame by using the new column order
# Display the data types of each column by using the dtypes Pandas function
new_column_order = ["City", "Country", "Lng", "Lat", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country       Lng      Lat  Max Temp  Humidity  \
# 0           Morondava      MG   44.2833 -20.2833     84.52        61
# 1         New Norfolk      AU  147.0587 -42.7826     69.93        27
# 2              Barrow      US -156.7887  71.2906     -0.38        71
# 3       Alice Springs      AU  133.8833 -23.7000     92.75        40
# 4          Karmaskaly      RU   56.1837  54.3709     -4.09        90
# 5          Filadelfia      US  -75.1638  39.9523     31.10        69
# 6           Abbeville      FR    1.8333  50.1000     46.36        73
# 7           Busselton      AU  115.3333 -33.6500     79.16        38
# 8  Comodoro Rivadavia      AR  -67.5000 -45.8667     49.86        87
# 9            Thompson      CA  -97.8558  55.7435     -0.24        85
#
#    Cloudiness  Wind Speed                 Date
# 0          39        2.98  2023-01-15 06:36:47
# 1           0        5.01  2023-01-15 06:36:48
# 2          40       20.71  2023-01-15 06:36:48
# 3          40       19.57  2023-01-15 06:32:22
# 4          99        9.48  2023-01-15 06:36:49
# 5          75       16.11  2023-01-15 06:34:37
# 6          77       19.39  2023-01-15 06:36:49
# 7           0       16.08  2023-01-15 06:36:50
# 8           0        3.44  2023-01-15 06:36:50
# 9         100        8.05  2023-01-15 06:36:51

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
